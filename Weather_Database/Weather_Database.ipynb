# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %% [markdown]
# # Retreaving the Neareast City

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 789

# %% [markdown]
# # Performing an API Call with the OpenWeatherMap

# %%
#Import dependencies
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rock sound
# Processing Record 2 of Set 1 | saint-philippe
# Processing Record 3 of Set 1 | ostrovnoy
# Processing Record 4 of Set 1 | takaka
# Processing Record 5 of Set 1 | bayan
# Processing Record 6 of Set 1 | port alfred
# Processing Record 7 of Set 1 | butaritari
# Processing Record 8 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 1 | upernavik
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | adrar
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | acari
# Processing Record 15 of Set 1 | hermanus
# Processing Record 16 of Set 1 | new norfolk
# Processing Record 17 of Set 1 | tokur
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | constitucion
# Processing Record 21 of Set 1 | bluff
# Processing Record 22 of Set 1 | barrow
# Processing Record 23 of Set 1 | gorontalo
# Processing Record 24 of Set 1 | san cristobal
# Processing Record 25 of Set 1 | kodiak
# Processing Record 26 of Set 1 | ribeira grande
# Processing Record 27 of Set 1 | hithadhoo
# Processing Record 28 of Set 1 | yellowknife
# Processing Record 29 of Set 1 | vaini
# Processing Record 30 of Set 1 | arraial do cabo
# Processing Record 31 of Set 1 | yulara
# Processing Record 32 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 1 | huancavelica
# Processing Record 34 of Set 1 | nagato
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | college
# Processing Record 37 of Set 1 | najran
# Processing Record 38 of Set 1 | cilaos
# Processing Record 39 of Set 1 | kruisfontein
# Processing Record 40 of Set 1 | meadow lake
# Processing Record 41 of Set 1 | marsabit
# Processing Record 42 of Set 1 | aykhal
# Processing Record 43 of Set 1 | kimbe
# Processing Record 44 of Set 1 | sur
# Processing Record 45 of Set 1 | uruana
# Processing Record 46 of Set 1 | port hedland
# Processing Record 47 of Set 1 | aklavik
# Processing Record 48 of Set 1 | kloulklubed
# Processing Record 49 of Set 1 | olafsvik
# Processing Record 50 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 2 | puerto ayora
# Processing Record 2 of Set 2 | grindavik
# Processing Record 3 of Set 2 | chokurdakh
# Processing Record 4 of Set 2 | valparaiso
# Processing Record 5 of Set 2 | sfantu gheorghe
# Processing Record 6 of Set 2 | hofn
# Processing Record 7 of Set 2 | tuktoyaktuk
# Processing Record 8 of Set 2 | busselton
# Processing Record 9 of Set 2 | lagoa
# Processing Record 10 of Set 2 | hilo
# Processing Record 11 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 2 | martapura
# Processing Record 13 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 2 | cape town
# Processing Record 15 of Set 2 | hovd
# Processing Record 16 of Set 2 | santa maria
# Processing Record 17 of Set 2 | rawson
# Processing Record 18 of Set 2 | komsomolskiy
# Processing Record 19 of Set 2 | georgetown
# Processing Record 20 of Set 2 | mpophomeni
# Processing Record 21 of Set 2 | mount gambier
# Processing Record 22 of Set 2 | vardo
# Processing Record 23 of Set 2 | lebu
# Processing Record 24 of Set 2 | auki
# Processing Record 25 of Set 2 | the valley
# Processing Record 26 of Set 2 | qaanaaq
# Processing Record 27 of Set 2 | havoysund
# Processing Record 28 of Set 2 | songjianghe
# Processing Record 29 of Set 2 | jamestown
# Processing Record 30 of Set 2 | tabialan
# City not found. Skipping...
# Processing Record 31 of Set 2 | banes
# Processing Record 32 of Set 2 | rio novo
# Processing Record 33 of Set 2 | tessalit
# Processing Record 34 of Set 2 | nikolskoye
# Processing Record 35 of Set 2 | hasaki
# Processing Record 36 of Set 2 | itarema
# Processing Record 37 of Set 2 | wagga wagga
# Processing Record 38 of Set 2 | isangel
# Processing Record 39 of Set 2 | mapiri
# Processing Record 40 of Set 2 | bur gabo
# City not found. Skipping...
# Processing Record 41 of Set 2 | chilchota
# Processing Record 42 of Set 2 | beringovskiy
# Processing Record 43 of Set 2 | kapaa
# Processing Record 44 of Set 2 | east london
# Processing Record 45 of Set 2 | balkhash
# Processing Record 46 of Set 2 | kabelvag
# Processing Record 47 of Set 2 | santa cruz de la palma
# Processing Record 48 of Set 2 | yarmouth
# Processing Record 49 of Set 2 | clyde river
# Processing Record 50 of Set 2 | cap malheureux
# Processing Record 1 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 3 | luorong
# Processing Record 3 of Set 3 | poum
# Processing Record 4 of Set 3 | polunochnoye
# Processing Record 5 of Set 3 | buritis
# Processing Record 6 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 7 of Set 3 | cabo san lucas
# Processing Record 8 of Set 3 | provideniya
# Processing Record 9 of Set 3 | viedma
# Processing Record 10 of Set 3 | castro
# Processing Record 11 of Set 3 | hobart
# Processing Record 12 of Set 3 | vitimskiy
# City not found. Skipping...
# Processing Record 13 of Set 3 | bethel
# Processing Record 14 of Set 3 | kerema
# Processing Record 15 of Set 3 | ilulissat
# Processing Record 16 of Set 3 | guerrero negro
# Processing Record 17 of Set 3 | celestun
# Processing Record 18 of Set 3 | whitianga
# Processing Record 19 of Set 3 | nuqui
# Processing Record 20 of Set 3 | punta
# Processing Record 21 of Set 3 | garowe
# Processing Record 22 of Set 3 | bud
# Processing Record 23 of Set 3 | port-cartier
# Processing Record 24 of Set 3 | suluq
# Processing Record 25 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 3 | vanimo
# Processing Record 27 of Set 3 | tasiilaq
# Processing Record 28 of Set 3 | meulaboh
# Processing Record 29 of Set 3 | cotacachi
# Processing Record 30 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 31 of Set 3 | carnarvon
# Processing Record 32 of Set 3 | nyurba
# Processing Record 33 of Set 3 | ous
# Processing Record 34 of Set 3 | altay
# Processing Record 35 of Set 3 | kouroussa
# Processing Record 36 of Set 3 | gwadar
# Processing Record 37 of Set 3 | saint george
# Processing Record 38 of Set 3 | le moule
# Processing Record 39 of Set 3 | bredasdorp
# Processing Record 40 of Set 3 | atambua
# Processing Record 41 of Set 3 | odienne
# Processing Record 42 of Set 3 | ponta do sol
# Processing Record 43 of Set 3 | torbay
# Processing Record 44 of Set 3 | melilla
# Processing Record 45 of Set 3 | peterongan
# Processing Record 46 of Set 3 | mahebourg
# Processing Record 47 of Set 3 | geraldton
# Processing Record 48 of Set 3 | mar del plata
# Processing Record 49 of Set 3 | takoradi
# Processing Record 50 of Set 3 | margate
# Processing Record 1 of Set 4 | svetlyy
# Processing Record 2 of Set 4 | zanjan
# Processing Record 3 of Set 4 | nanortalik
# Processing Record 4 of Set 4 | vuktyl
# Processing Record 5 of Set 4 | huangzhai
# Processing Record 6 of Set 4 | sawtell
# Processing Record 7 of Set 4 | palmer
# Processing Record 8 of Set 4 | haines junction
# Processing Record 9 of Set 4 | independence
# Processing Record 10 of Set 4 | dikson
# Processing Record 11 of Set 4 | nago
# Processing Record 12 of Set 4 | anzhero-sudzhensk
# Processing Record 13 of Set 4 | kingman
# Processing Record 14 of Set 4 | port elizabeth
# Processing Record 15 of Set 4 | majene
# Processing Record 16 of Set 4 | shelburne
# Processing Record 17 of Set 4 | abyek
# Processing Record 18 of Set 4 | namatanai
# Processing Record 19 of Set 4 | fenoarivo atsinanana
# Processing Record 20 of Set 4 | san buenaventura
# Processing Record 21 of Set 4 | doha
# Processing Record 22 of Set 4 | caranavi
# Processing Record 23 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 4 | sobolevo
# Processing Record 25 of Set 4 | salalah
# Processing Record 26 of Set 4 | tocopilla
# Processing Record 27 of Set 4 | sao joao da barra
# Processing Record 28 of Set 4 | fuling
# Processing Record 29 of Set 4 | ahuimanu
# Processing Record 30 of Set 4 | yarada
# Processing Record 31 of Set 4 | linguere
# Processing Record 32 of Set 4 | thompson
# Processing Record 33 of Set 4 | norman wells
# Processing Record 34 of Set 4 | riverton
# Processing Record 35 of Set 4 | ahipara
# Processing Record 36 of Set 4 | laguna
# Processing Record 37 of Set 4 | port lincoln
# Processing Record 38 of Set 4 | shitanjing
# Processing Record 39 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 4 | savinskiy
# Processing Record 41 of Set 4 | copiapo
# Processing Record 42 of Set 4 | fortuna
# Processing Record 43 of Set 4 | lasa
# Processing Record 44 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 4 | kaeo
# Processing Record 46 of Set 4 | maniitsoq
# Processing Record 47 of Set 4 | yamada
# Processing Record 48 of Set 4 | buin
# Processing Record 49 of Set 4 | benjamin constant
# Processing Record 50 of Set 4 | kupang
# Processing Record 1 of Set 5 | horsham
# Processing Record 2 of Set 5 | ilheus
# Processing Record 3 of Set 5 | puerto palomas
# Processing Record 4 of Set 5 | kharp
# Processing Record 5 of Set 5 | mazamari
# Processing Record 6 of Set 5 | akdepe
# Processing Record 7 of Set 5 | avarua
# Processing Record 8 of Set 5 | buala
# Processing Record 9 of Set 5 | saskylakh
# Processing Record 10 of Set 5 | maryville
# Processing Record 11 of Set 5 | qaqortoq
# Processing Record 12 of Set 5 | kaitangata
# Processing Record 13 of Set 5 | san quintin
# Processing Record 14 of Set 5 | bambous virieux
# Processing Record 15 of Set 5 | nelson bay
# Processing Record 16 of Set 5 | havre-saint-pierre
# Processing Record 17 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 5 | myanaung
# Processing Record 19 of Set 5 | sinnamary
# Processing Record 20 of Set 5 | airai
# Processing Record 21 of Set 5 | burnie
# Processing Record 22 of Set 5 | kavieng
# Processing Record 23 of Set 5 | tiksi
# Processing Record 24 of Set 5 | shambu
# Processing Record 25 of Set 5 | clonakilty
# Processing Record 26 of Set 5 | megion
# Processing Record 27 of Set 5 | port-gentil
# Processing Record 28 of Set 5 | vila franca do campo
# Processing Record 29 of Set 5 | khatanga
# Processing Record 30 of Set 5 | roma
# Processing Record 31 of Set 5 | pisco
# Processing Record 32 of Set 5 | iqaluit
# Processing Record 33 of Set 5 | hanmer springs
# Processing Record 34 of Set 5 | praya
# Processing Record 35 of Set 5 | sistranda
# Processing Record 36 of Set 5 | sao filipe
# Processing Record 37 of Set 5 | coihaique
# Processing Record 38 of Set 5 | kilrush
# Processing Record 39 of Set 5 | klaksvik
# Processing Record 40 of Set 5 | evensk
# Processing Record 41 of Set 5 | puerto leguizamo
# Processing Record 42 of Set 5 | lokosovo
# Processing Record 43 of Set 5 | cayenne
# Processing Record 44 of Set 5 | fairbanks
# Processing Record 45 of Set 5 | kandrian
# Processing Record 46 of Set 5 | umm lajj
# Processing Record 47 of Set 5 | wanning
# Processing Record 48 of Set 5 | te anau
# Processing Record 49 of Set 5 | san patricio
# Processing Record 50 of Set 5 | kysyl-syr
# Processing Record 1 of Set 6 | cidreira
# Processing Record 2 of Set 6 | diplo
# Processing Record 3 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 4 of Set 6 | opuwo
# Processing Record 5 of Set 6 | dubrovytsya
# Processing Record 6 of Set 6 | otavi
# Processing Record 7 of Set 6 | longyearbyen
# Processing Record 8 of Set 6 | gasa
# Processing Record 9 of Set 6 | mantua
# Processing Record 10 of Set 6 | mehamn
# Processing Record 11 of Set 6 | kamaishi
# Processing Record 12 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 13 of Set 6 | talnakh
# Processing Record 14 of Set 6 | lompoc
# Processing Record 15 of Set 6 | farkhor
# Processing Record 16 of Set 6 | alta floresta
# Processing Record 17 of Set 6 | prince george
# Processing Record 18 of Set 6 | amnat charoen
# Processing Record 19 of Set 6 | oranjemund
# Processing Record 20 of Set 6 | humaita
# Processing Record 21 of Set 6 | santa vitoria do palmar
# Processing Record 22 of Set 6 | marsh harbour
# Processing Record 23 of Set 6 | puerto rico
# Processing Record 24 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 6 | lumberton
# Processing Record 26 of Set 6 | inirida
# Processing Record 27 of Set 6 | jevargi
# Processing Record 28 of Set 6 | bossangoa
# Processing Record 29 of Set 6 | northeim
# Processing Record 30 of Set 6 | houma
# Processing Record 31 of Set 6 | chachoengsao
# Processing Record 32 of Set 6 | axim
# Processing Record 33 of Set 6 | koungou
# Processing Record 34 of Set 6 | kure
# Processing Record 35 of Set 6 | victoria
# Processing Record 36 of Set 6 | kiunga
# Processing Record 37 of Set 6 | tual
# Processing Record 38 of Set 6 | ponta delgada
# Processing Record 39 of Set 6 | nanchang
# Processing Record 40 of Set 6 | jalu
# Processing Record 41 of Set 6 | hervey bay
# Processing Record 42 of Set 6 | touros
# Processing Record 43 of Set 6 | maragogi
# Processing Record 44 of Set 6 | lufilufi
# Processing Record 45 of Set 6 | bengkulu
# Processing Record 46 of Set 6 | kapit
# Processing Record 47 of Set 6 | plettenberg bay
# Processing Record 48 of Set 6 | port blair
# Processing Record 49 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 50 of Set 6 | williston
# Processing Record 1 of Set 7 | slave lake
# Processing Record 2 of Set 7 | kavaratti
# Processing Record 3 of Set 7 | oliver
# Processing Record 4 of Set 7 | batagay-alyta
# Processing Record 5 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 7 | tagusao
# Processing Record 7 of Set 7 | awjilah
# Processing Record 8 of Set 7 | ekibastuz
# Processing Record 9 of Set 7 | sorland
# Processing Record 10 of Set 7 | iralaya
# Processing Record 11 of Set 7 | praia
# Processing Record 12 of Set 7 | moron
# Processing Record 13 of Set 7 | sabang
# Processing Record 14 of Set 7 | khandbari
# Processing Record 15 of Set 7 | ust-omchug
# Processing Record 16 of Set 7 | halmstad
# Processing Record 17 of Set 7 | westport
# Processing Record 18 of Set 7 | kaputa
# Processing Record 19 of Set 7 | ketchikan
# Processing Record 20 of Set 7 | dwarka
# Processing Record 21 of Set 7 | trincomalee
# Processing Record 22 of Set 7 | amapa
# Processing Record 23 of Set 7 | kolpny
# Processing Record 24 of Set 7 | la crosse
# Processing Record 25 of Set 7 | hobyo
# Processing Record 26 of Set 7 | point pedro
# Processing Record 27 of Set 7 | anadyr
# Processing Record 28 of Set 7 | yiyang
# Processing Record 29 of Set 7 | san ramon
# Processing Record 30 of Set 7 | mount vernon
# Processing Record 31 of Set 7 | sept-iles
# Processing Record 32 of Set 7 | wagar
# Processing Record 33 of Set 7 | faanui
# Processing Record 34 of Set 7 | yerbogachen
# Processing Record 35 of Set 7 | kaniama
# Processing Record 36 of Set 7 | kahului
# Processing Record 37 of Set 7 | bintulu
# Processing Record 38 of Set 7 | la victoria
# Processing Record 39 of Set 7 | kismayo
# Processing Record 40 of Set 7 | ibatiba
# Processing Record 41 of Set 7 | gladstone
# Processing Record 42 of Set 7 | severo-kurilsk
# Processing Record 43 of Set 7 | ust-maya
# Processing Record 44 of Set 7 | vestmannaeyjar
# Processing Record 45 of Set 7 | caconda
# Processing Record 46 of Set 7 | marathon
# Processing Record 47 of Set 7 | ormara
# Processing Record 48 of Set 7 | souillac
# Processing Record 49 of Set 7 | hami
# Processing Record 50 of Set 7 | luang prabang
# Processing Record 1 of Set 8 | belvedere marittimo
# Processing Record 2 of Set 8 | eureka
# Processing Record 3 of Set 8 | harper
# Processing Record 4 of Set 8 | cah ab
# City not found. Skipping...
# Processing Record 5 of Set 8 | bosaso
# Processing Record 6 of Set 8 | prado
# Processing Record 7 of Set 8 | rocha
# Processing Record 8 of Set 8 | misratah
# Processing Record 9 of Set 8 | uvira
# Processing Record 10 of Set 8 | lukovetskiy
# Processing Record 11 of Set 8 | saldanha
# Processing Record 12 of Set 8 | porterville
# Processing Record 13 of Set 8 | rafaela
# Processing Record 14 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 8 | disna
# Processing Record 16 of Set 8 | sivas
# Processing Record 17 of Set 8 | solwezi
# Processing Record 18 of Set 8 | nantucket
# Processing Record 19 of Set 8 | kuytun
# Processing Record 20 of Set 8 | kitimat
# Processing Record 21 of Set 8 | cherskiy
# Processing Record 22 of Set 8 | nome
# Processing Record 23 of Set 8 | sarab
# Processing Record 24 of Set 8 | jackson
# Processing Record 25 of Set 8 | quesnel
# Processing Record 26 of Set 8 | chuy
# Processing Record 27 of Set 8 | asfi
# Processing Record 28 of Set 8 | los andes
# Processing Record 29 of Set 8 | vilhena
# Processing Record 30 of Set 8 | pacific grove
# Processing Record 31 of Set 8 | bronnoysund
# Processing Record 32 of Set 8 | pasighat
# Processing Record 33 of Set 8 | kudahuvadhoo
# Processing Record 34 of Set 8 | mentok
# City not found. Skipping...
# Processing Record 35 of Set 8 | yar-sale
# Processing Record 36 of Set 8 | kostroma
# Processing Record 37 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 38 of Set 8 | pierre
# Processing Record 39 of Set 8 | rorvik
# Processing Record 40 of Set 8 | dongsheng
# Processing Record 41 of Set 8 | flers
# Processing Record 42 of Set 8 | akropong
# Processing Record 43 of Set 8 | tura
# Processing Record 44 of Set 8 | marawi
# Processing Record 45 of Set 8 | shache
# Processing Record 46 of Set 8 | andros town
# Processing Record 47 of Set 8 | agadez
# Processing Record 48 of Set 8 | santa isabel
# Processing Record 49 of Set 8 | barvinkove
# Processing Record 50 of Set 8 | maningrida
# Processing Record 1 of Set 9 | khani
# Processing Record 2 of Set 9 | necochea
# Processing Record 3 of Set 9 | collie
# Processing Record 4 of Set 9 | tuatapere
# Processing Record 5 of Set 9 | payo
# Processing Record 6 of Set 9 | sao gabriel da cachoeira
# Processing Record 7 of Set 9 | taltal
# Processing Record 8 of Set 9 | russell
# Processing Record 9 of Set 9 | tapaua
# City not found. Skipping...
# Processing Record 10 of Set 9 | tiznit
# Processing Record 11 of Set 9 | leh
# Processing Record 12 of Set 9 | port hawkesbury
# Processing Record 13 of Set 9 | gizo
# Processing Record 14 of Set 9 | kankan
# Processing Record 15 of Set 9 | avera
# Processing Record 16 of Set 9 | cefalu
# Processing Record 17 of Set 9 | esperance
# Processing Record 18 of Set 9 | salinopolis
# Processing Record 19 of Set 9 | pyapon
# Processing Record 20 of Set 9 | alugan
# Processing Record 21 of Set 9 | araouane
# Processing Record 22 of Set 9 | saint-pierre
# Processing Record 23 of Set 9 | morondava
# Processing Record 24 of Set 9 | umm kaddadah
# Processing Record 25 of Set 9 | aguimes
# Processing Record 26 of Set 9 | sanmenxia
# Processing Record 27 of Set 9 | slimnic
# Processing Record 28 of Set 9 | buraydah
# Processing Record 29 of Set 9 | saint-augustin
# Processing Record 30 of Set 9 | halifax
# Processing Record 31 of Set 9 | gazojak
# Processing Record 32 of Set 9 | roald
# Processing Record 33 of Set 9 | middelburg
# Processing Record 34 of Set 9 | hay river
# Processing Record 35 of Set 9 | ust-kulom
# Processing Record 36 of Set 9 | marquard
# Processing Record 37 of Set 9 | half moon bay
# Processing Record 38 of Set 9 | vrangel
# Processing Record 39 of Set 9 | coquimbo
# Processing Record 40 of Set 9 | alibag
# Processing Record 41 of Set 9 | gat
# Processing Record 42 of Set 9 | carapegua
# Processing Record 43 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 45 of Set 9 | alice springs
# Processing Record 46 of Set 9 | concepcion
# Processing Record 47 of Set 9 | katsuura
# Processing Record 48 of Set 9 | conceicao da barra
# Processing Record 49 of Set 9 | ulladulla
# Processing Record 50 of Set 9 | jomalig
# City not found. Skipping...
# Processing Record 1 of Set 10 | rio grande
# Processing Record 2 of Set 10 | jambi
# Processing Record 3 of Set 10 | nicoya
# Processing Record 4 of Set 10 | neuquen
# Processing Record 5 of Set 10 | kabo
# Processing Record 6 of Set 10 | susuman
# Processing Record 7 of Set 10 | pevek
# Processing Record 8 of Set 10 | fort saint john
# City not found. Skipping...
# Processing Record 9 of Set 10 | codrington
# Processing Record 10 of Set 10 | clyde
# Processing Record 11 of Set 10 | portland
# Processing Record 12 of Set 10 | athabasca
# Processing Record 13 of Set 10 | sorso
# Processing Record 14 of Set 10 | flinders
# Processing Record 15 of Set 10 | daru
# Processing Record 16 of Set 10 | rabat
# Processing Record 17 of Set 10 | ballina
# Processing Record 18 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 19 of Set 10 | ligaya
# Processing Record 20 of Set 10 | bumba
# Processing Record 21 of Set 10 | pahrump
# Processing Record 22 of Set 10 | zhezkazgan
# Processing Record 23 of Set 10 | sitka
# Processing Record 24 of Set 10 | monte alegre de sergipe
# Processing Record 25 of Set 10 | omboue
# Processing Record 26 of Set 10 | teya
# Processing Record 27 of Set 10 | chaochou
# City not found. Skipping...
# Processing Record 28 of Set 10 | sogdiondon
# City not found. Skipping...
# Processing Record 29 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 10 | santiago del estero
# Processing Record 31 of Set 10 | vilyuysk
# Processing Record 32 of Set 10 | ust-tsilma
# Processing Record 33 of Set 10 | salym
# Processing Record 34 of Set 10 | starosubkhangulovo
# Processing Record 35 of Set 10 | novomykolayivka
# Processing Record 36 of Set 10 | rio claro
# Processing Record 37 of Set 10 | ancud
# Processing Record 38 of Set 10 | gamba
# Processing Record 39 of Set 10 | ushtobe
# Processing Record 40 of Set 10 | caorle
# Processing Record 41 of Set 10 | mezen
# Processing Record 42 of Set 10 | balikpapan
# Processing Record 43 of Set 10 | solovetskiy
# City not found. Skipping...
# Processing Record 44 of Set 10 | oistins
# Processing Record 45 of Set 10 | namibe
# Processing Record 46 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 10 | karratha
# Processing Record 48 of Set 10 | skutec
# Processing Record 49 of Set 10 | bozuyuk
# Processing Record 50 of Set 10 | khandyga
# Processing Record 1 of Set 11 | jawa
# Processing Record 2 of Set 11 | lyubim
# Processing Record 3 of Set 11 | sragen
# Processing Record 4 of Set 11 | paamiut
# Processing Record 5 of Set 11 | vao
# Processing Record 6 of Set 11 | asau
# Processing Record 7 of Set 11 | lazaro cardenas
# Processing Record 8 of Set 11 | asayita
# City not found. Skipping...
# Processing Record 9 of Set 11 | bandarbeyla
# Processing Record 10 of Set 11 | faranah
# Processing Record 11 of Set 11 | canutama
# Processing Record 12 of Set 11 | vila velha
# Processing Record 13 of Set 11 | santa rosa
# Processing Record 14 of Set 11 | riberalta
# Processing Record 15 of Set 11 | tabuk
# Processing Record 16 of Set 11 | luderitz
# Processing Record 17 of Set 11 | zile
# Processing Record 18 of Set 11 | tias
# Processing Record 19 of Set 11 | dalbeattie
# Processing Record 20 of Set 11 | aban
# Processing Record 21 of Set 11 | uruzgan
# Processing Record 22 of Set 11 | raga
# Processing Record 23 of Set 11 | vila
# Processing Record 24 of Set 11 | laibin
# Processing Record 25 of Set 11 | west lake stevens
# Processing Record 26 of Set 11 | atherton
# Processing Record 27 of Set 11 | maralal
# Processing Record 28 of Set 11 | solnechnyy
# Processing Record 29 of Set 11 | malbug
# Processing Record 30 of Set 11 | vila do maio
# Processing Record 31 of Set 11 | danjiangkou
# Processing Record 32 of Set 11 | markala
# Processing Record 33 of Set 11 | predivinsk
# Processing Record 34 of Set 11 | acapulco
# Processing Record 35 of Set 11 | beisfjord
# Processing Record 36 of Set 11 | kaupanger
# Processing Record 37 of Set 11 | pandan niog
# Processing Record 38 of Set 11 | bowen
# Processing Record 39 of Set 11 | hinton
# Processing Record 40 of Set 11 | mae chan
# Processing Record 41 of Set 11 | hamilton
# Processing Record 42 of Set 11 | mareeba
# Processing Record 43 of Set 11 | shingu
# Processing Record 44 of Set 11 | maicao
# Processing Record 45 of Set 11 | waipawa
# Processing Record 46 of Set 11 | broken hill
# Processing Record 47 of Set 11 | samarai
# Processing Record 48 of Set 11 | parana
# Processing Record 49 of Set 11 | chitral
# Processing Record 50 of Set 11 | zemetchino
# Processing Record 1 of Set 12 | atar
# Processing Record 2 of Set 12 | shizunai
# Processing Record 3 of Set 12 | northam
# Processing Record 4 of Set 12 | bathsheba
# Processing Record 5 of Set 12 | grand gaube
# Processing Record 6 of Set 12 | sumenep
# Processing Record 7 of Set 12 | cabedelo
# Processing Record 8 of Set 12 | smithers
# Processing Record 9 of Set 12 | vienna
# Processing Record 10 of Set 12 | vohibinany
# Processing Record 11 of Set 12 | dargaville
# Processing Record 12 of Set 12 | marzuq
# Processing Record 13 of Set 12 | lebedyan
# Processing Record 14 of Set 12 | redlands
# Processing Record 15 of Set 12 | nouadhibou
# Processing Record 16 of Set 12 | rong kwang
# Processing Record 17 of Set 12 | baykit
# Processing Record 18 of Set 12 | saint-francois
# Processing Record 19 of Set 12 | presidencia roque saenz pena
# Processing Record 20 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 21 of Set 12 | shenjiamen
# Processing Record 22 of Set 12 | etchojoa
# Processing Record 23 of Set 12 | kang
# Processing Record 24 of Set 12 | scharnstein
# Processing Record 25 of Set 12 | salinas
# Processing Record 26 of Set 12 | barkhan
# Processing Record 27 of Set 12 | narsaq
# Processing Record 28 of Set 12 | aksehir
# Processing Record 29 of Set 12 | nikel
# Processing Record 30 of Set 12 | menongue
# Processing Record 31 of Set 12 | ionia
# Processing Record 32 of Set 12 | ixtapa
# Processing Record 33 of Set 12 | berlevag
# Processing Record 34 of Set 12 | dunedin
# Processing Record 35 of Set 12 | kurchum
# Processing Record 36 of Set 12 | varhaug
# Processing Record 37 of Set 12 | yirol
# City not found. Skipping...
# Processing Record 38 of Set 12 | rundu
# Processing Record 39 of Set 12 | perpignan
# Processing Record 40 of Set 12 | along
# Processing Record 41 of Set 12 | natal
# Processing Record 42 of Set 12 | methoni
# Processing Record 43 of Set 12 | asyut
# Processing Record 44 of Set 12 | churapcha
# Processing Record 45 of Set 12 | mahibadhoo
# Processing Record 46 of Set 12 | daro
# Processing Record 47 of Set 12 | miandrivazo
# Processing Record 48 of Set 12 | duku
# Processing Record 49 of Set 12 | baglung
# Processing Record 50 of Set 12 | tateyama
# Processing Record 1 of Set 13 | merauke
# Processing Record 2 of Set 13 | ribas do rio pardo
# Processing Record 3 of Set 13 | huambo
# Processing Record 4 of Set 13 | honiara
# Processing Record 5 of Set 13 | lorengau
# Processing Record 6 of Set 13 | nalut
# Processing Record 7 of Set 13 | eyl
# Processing Record 8 of Set 13 | ambilobe
# Processing Record 9 of Set 13 | fare
# Processing Record 10 of Set 13 | aloleng
# Processing Record 11 of Set 13 | wajir
# Processing Record 12 of Set 13 | obidos
# Processing Record 13 of Set 13 | kuvshinovo
# Processing Record 14 of Set 13 | flin flon
# Processing Record 15 of Set 13 | athens
# Processing Record 16 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 17 of Set 13 | yaan
# Processing Record 18 of Set 13 | wucheng
# Processing Record 19 of Set 13 | geylegphug
# City not found. Skipping...
# Processing Record 20 of Set 13 | lugovoy
# Processing Record 21 of Set 13 | horten
# Processing Record 22 of Set 13 | chara
# Processing Record 23 of Set 13 | dzerzhinskoye
# Processing Record 24 of Set 13 | whitley bay
# Processing Record 25 of Set 13 | tabou
# Processing Record 26 of Set 13 | lata
# Processing Record 27 of Set 13 | manzil tamim
# City not found. Skipping...
# Processing Record 28 of Set 13 | pamanukan
# Processing Record 29 of Set 13 | bere
# Processing Record 30 of Set 13 | hualmay
# Processing Record 31 of Set 13 | prince rupert
# Processing Record 32 of Set 13 | walvis bay
# Processing Record 33 of Set 13 | shar
# Processing Record 34 of Set 13 | sioux falls
# Processing Record 35 of Set 13 | christchurch
# Processing Record 36 of Set 13 | jurado
# Processing Record 37 of Set 13 | dudinka
# Processing Record 38 of Set 13 | tilichiki
# Processing Record 39 of Set 13 | osa
# Processing Record 40 of Set 13 | bishop auckland
# Processing Record 41 of Set 13 | kalabo
# Processing Record 42 of Set 13 | canete
# Processing Record 43 of Set 13 | alofi
# Processing Record 44 of Set 13 | cockburn town
# Processing Record 45 of Set 13 | vanersborg
# Processing Record 46 of Set 13 | pontianak
# Processing Record 47 of Set 13 | havelock
# Processing Record 48 of Set 13 | perth
# Processing Record 49 of Set 13 | labuhan
# Processing Record 50 of Set 13 | richards bay
# Processing Record 1 of Set 14 | hatta
# Processing Record 2 of Set 14 | san vicente
# Processing Record 3 of Set 14 | impfondo
# Processing Record 4 of Set 14 | usinsk
# Processing Record 5 of Set 14 | piet retief
# Processing Record 6 of Set 14 | forbes
# Processing Record 7 of Set 14 | abu samrah
# Processing Record 8 of Set 14 | inuvik
# Processing Record 9 of Set 14 | lewisporte
# Processing Record 10 of Set 14 | senges
# Processing Record 11 of Set 14 | kutum
# Processing Record 12 of Set 14 | lichinga
# Processing Record 13 of Set 14 | olinda
# Processing Record 14 of Set 14 | juneau
# Processing Record 15 of Set 14 | denpasar
# Processing Record 16 of Set 14 | nola
# Processing Record 17 of Set 14 | puksoozero
# Processing Record 18 of Set 14 | presidente medici
# Processing Record 19 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 20 of Set 14 | loandjili
# Processing Record 21 of Set 14 | tomatlan
# Processing Record 22 of Set 14 | emba
# Processing Record 23 of Set 14 | taoudenni
# Processing Record 24 of Set 14 | rock springs
# Processing Record 25 of Set 14 | lakhdenpokhya
# Processing Record 26 of Set 14 | valparai
# Processing Record 27 of Set 14 | narasannapeta
# Processing Record 28 of Set 14 | gilgil
# City not found. Skipping...
# Processing Record 29 of Set 14 | novolvovsk
# City not found. Skipping...
# Processing Record 30 of Set 14 | sakaiminato
# Processing Record 31 of Set 14 | agua prieta
# Processing Record 32 of Set 14 | fukue
# Processing Record 33 of Set 14 | bilma
# Processing Record 34 of Set 14 | kailua
# Processing Record 35 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 36 of Set 14 | aginskoye
# Processing Record 37 of Set 14 | ucluelet
# Processing Record 38 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 14 | manaure
# Processing Record 40 of Set 14 | charters towers
# Processing Record 41 of Set 14 | sleaford
# Processing Record 42 of Set 14 | indian head
# Processing Record 43 of Set 14 | gazanjyk
# Processing Record 44 of Set 14 | krasnoselkup
# Processing Record 45 of Set 14 | kadarkut
# Processing Record 46 of Set 14 | tazovskiy
# Processing Record 47 of Set 14 | riyadh
# Processing Record 48 of Set 14 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 14 | korla
# Processing Record 50 of Set 14 | kodinsk
# Processing Record 1 of Set 15 | saint-denis
# Processing Record 2 of Set 15 | port macquarie
# Processing Record 3 of Set 15 | south venice
# Processing Record 4 of Set 15 | mopipi
# Processing Record 5 of Set 15 | acajutla
# Processing Record 6 of Set 15 | tromso
# Processing Record 7 of Set 15 | egvekinot
# Processing Record 8 of Set 15 | san juan de los morros
# Processing Record 9 of Set 15 | srednekolymsk
# Processing Record 10 of Set 15 | los llanos de aridane
# Processing Record 11 of Set 15 | honningsvag
# Processing Record 12 of Set 15 | lauingen
# Processing Record 13 of Set 15 | conceicao do araguaia
# Processing Record 14 of Set 15 | el limon
# Processing Record 15 of Set 15 | prieska
# Processing Record 16 of Set 15 | lavrentiya
# Processing Record 17 of Set 15 | hegang
# Processing Record 18 of Set 15 | atbasar
# Processing Record 19 of Set 15 | ossora
# Processing Record 20 of Set 15 | sakakah
# Processing Record 21 of Set 15 | fort nelson
# Processing Record 22 of Set 15 | enshi
# Processing Record 23 of Set 15 | kemijarvi
# Processing Record 24 of Set 15 | mount isa
# Processing Record 25 of Set 15 | chifeng
# Processing Record 26 of Set 15 | bilibino
# Processing Record 27 of Set 15 | dahuk
# Processing Record 28 of Set 15 | general pico
# Processing Record 29 of Set 15 | pakokku
# Processing Record 30 of Set 15 | ust-koksa
# Processing Record 31 of Set 15 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 15 | padang
# Processing Record 33 of Set 15 | bonavista
# Processing Record 34 of Set 15 | cabra
# Processing Record 35 of Set 15 | lonevag
# Processing Record 36 of Set 15 | krasne
# Processing Record 37 of Set 15 | carutapera
# Processing Record 38 of Set 15 | placido de castro
# Processing Record 39 of Set 15 | rio gallegos
# Processing Record 40 of Set 15 | scottsburgh
# City not found. Skipping...
# Processing Record 41 of Set 15 | murgab
# Processing Record 42 of Set 15 | xinyang
# Processing Record 43 of Set 15 | ubinskoye
# Processing Record 44 of Set 15 | sumbawa
# City not found. Skipping...
# Processing Record 45 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 46 of Set 15 | road town
# Processing Record 47 of Set 15 | zafarwal
# Processing Record 48 of Set 15 | ugoofaaru
# Processing Record 49 of Set 15 | pouebo
# Processing Record 50 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 16 | chicama
# Processing Record 2 of Set 16 | thinadhoo
# Processing Record 3 of Set 16 | durres
# Processing Record 4 of Set 16 | san leandro
# Processing Record 5 of Set 16 | isilkul
# Processing Record 6 of Set 16 | basco
# Processing Record 7 of Set 16 | dutse
# Processing Record 8 of Set 16 | emerald
# Processing Record 9 of Set 16 | betanzos
# Processing Record 10 of Set 16 | limoeiro do ajuru
# Processing Record 11 of Set 16 | timizart
# Processing Record 12 of Set 16 | brownsville
# Processing Record 13 of Set 16 | kambove
# Processing Record 14 of Set 16 | shumskiy
# Processing Record 15 of Set 16 | kamenka
# Processing Record 16 of Set 16 | santa rosalia
# Processing Record 17 of Set 16 | pangnirtung
# Processing Record 18 of Set 16 | owerri
# Processing Record 19 of Set 16 | reconquista
# Processing Record 20 of Set 16 | san luis
# Processing Record 21 of Set 16 | balakhta
# Processing Record 22 of Set 16 | matara
# Processing Record 23 of Set 16 | gornyy
# Processing Record 24 of Set 16 | harbour breton
# Processing Record 25 of Set 16 | pacifica
# Processing Record 26 of Set 16 | poronaysk
# Processing Record 27 of Set 16 | north bend
# Processing Record 28 of Set 16 | igarka
# Processing Record 29 of Set 16 | hendijan
# City not found. Skipping...
# Processing Record 30 of Set 16 | the pas
# Processing Record 31 of Set 16 | cachoeiro de itapemirim
# Processing Record 32 of Set 16 | pemberton
# Processing Record 33 of Set 16 | katangli
# Processing Record 34 of Set 16 | troitsko-pechorsk
# Processing Record 35 of Set 16 | andenes
# Processing Record 36 of Set 16 | san policarpo
# Processing Record 37 of Set 16 | buguruslan
# Processing Record 38 of Set 16 | henties bay
# Processing Record 39 of Set 16 | la reforma
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 736

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Rock Sound      BS  24.9000  -76.2000     78.78        83          62
# 1  Saint-Philippe      RE -21.3585   55.7679     80.15        78          57
# 2       Ostrovnoy      RU  68.0531   39.5131     43.90        63          45
# 3          Takaka      NZ -40.8500  172.8000     57.56        96         100
# 4           Bayan      CN  46.0833  127.4000     69.55        51          32
# 5     Port Alfred      ZA -33.5906   26.8910     67.10        28           0
# 6      Butaritari      KI   3.0707  172.7902     82.60        72           4
# 7       Upernavik      GL  72.7868  -56.1549     34.14        81           0
# 8         Rikitea      PF -23.1203 -134.9692     75.90        84         100
# 9          Atuona      PF  -9.8000 -139.0333     79.20        70          10
#
#    Wind Speed Current Description
# 0       19.46       broken clouds
# 1        7.09          light rain
# 2       13.44    scattered clouds
# 3        5.44     overcast clouds
# 4        5.53    scattered clouds
# 5        8.34           clear sky
# 6        2.91           clear sky
# 7        3.33           clear sky
# 8       17.78          light rain
# 9       14.34           clear sky

# %%
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
